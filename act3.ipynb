# %% [markdown]
# <h2>DANDO, ASHLEI LUIEZ</h2>
# <h2>BSIT-3A</h2>

# %%
# !pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in c:\users\charles\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\charles\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\charles\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\charles\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (2.3.2)
# Requirement already satisfied: requests in c:\users\charles\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in c:\users\charles\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\charles\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\charles\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\charles\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\charles\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\charles\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->folium) (2025.8.3)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import folium
from folium.plugins import HeatMap
import warnings
warnings.filterwarnings('ignore')

# %%
accidents = pd.read_csv('uk_road_accident.csv')

# %%
accidents
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# 1                          Daylight  Kensington and Chelsea  -0.173647
# 2       Darkness - lighting unknown  Kensington and Chelsea  -0.210215
# 3                          Daylight  Kensington and Chelsea  -0.202731
# 4             Darkness - lights lit  Kensington and Chelsea  -0.192487
# ...                             ...                     ...        ...
# 660674                     Daylight                Highland  -3.467828
# 660675       Darkness - no lighting                Highland  -3.809281
# 660676                     Daylight                Highland  -3.862727
# 660677       Darkness - no lighting                Highland  -3.823997
# 660678                     Daylight                Highland  -3.895673
#
#         Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                          1                   2                     Dry
# 1                          1                   2             Wet or damp
# 2                          1                   3                     Dry
# 3                          1                   4                     Dry
# 4                          1                   2                     Dry
# ...                      ...                 ...                     ...
# 660674                     2                   1                     Dry
# 660675                     1                   1            Frost or ice
# 660676                     1                   3            Frost or ice
# 660677                     1                   2             Wet or damp
# 660678                     1                   1             Wet or damp
#
#                  Road_Type Urban_or_Rural_Area     Weather_Conditions  \
# 0       Single carriageway               Urban     Fine no high winds
# 1       Single carriageway               Urban  Raining no high winds
# 2                      NaN               Urban                    NaN
# 3       Single carriageway               Urban     Fine no high winds
# 4                      NaN               Urban                    NaN
# ...                    ...                 ...                    ...
# 660674  Single carriageway               Rural     Fine no high winds
# 660675  Single carriageway               Rural     Fine no high winds
# 660676  Single carriageway               Rural     Fine no high winds
# 660677  Single carriageway               Rural     Fine no high winds
# 660678    Dual carriageway               Rural  Snowing no high winds
#
#                                 Vehicle_Type
# 0                                        Car
# 1                                        Car
# 2                      Taxi/Private hire car
# 3       Bus or coach (17 or more pass seats)
# 4                              Other vehicle
# ...                                      ...
# 660674                                   Car
# 660675                                   Car
# 660676                                   Car
# 660677                 Motorcycle over 500cc
# 660678                                   Car
#
# [660679 rows x 14 columns]

# %%
accidents['Accident Date'] = accidents['Accident Date'].str.strip()

accidents['Accident Date'] = accidents['Accident Date'].astype('str')

accidents['Accident Date'] = accidents['Accident Date'].str.replace('/', '-')

accidents['Accident Date'] = pd.to_datetime(accidents['Accident Date'], dayfirst=True, errors='coerce')

# %%
accidents.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %%
accidents['Latitude'] = accidents['Latitude'].fillna(accidents['Latitude'].mode()[0])
accidents['Longitude'] = accidents['Longitude'].fillna(accidents['Longitude'].mode()[0])
accidents['Road_Surface_Conditions'] = accidents['Road_Surface_Conditions'].fillna('unaccounted')
accidents['Road_Type'] = accidents['Road_Type'].fillna('unaccounted')
accidents['Urban_or_Rural_Area'] = accidents['Urban_or_Rural_Area'].fillna('unaccounted')
accidents['Weather_Conditions'] = accidents['Weather_Conditions'].fillna(accidents['Weather_Conditions'].mode()[0])

# %%
accidents['Year'] = accidents['Accident Date'].dt.year
accidents['Month'] = accidents['Accident Date'].dt.month
accidents['Day'] = accidents['Accident Date'].dt.day
accidents['DayOfWeek'] = accidents['Accident Date'].dt.dayofweek
accidents.isnull().sum()
# Out:
# Index                      0
# Accident_Severity          0
# Accident Date              0
# Latitude                   0
# Light_Conditions           0
# District Area              0
# Longitude                  0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# Year                       0
# Month                      0
# Day                        0
# DayOfWeek                  0
# dtype: int64

# %% [markdown]
# <h2>1. What is the distribution of accident severity (Slight, Serious, Fatal)?</h2>

# %%
accidents['Accident_Severity'].value_counts()
# Out:
# Accident_Severity
# Slight     563801
# Serious     88217
# Fatal        8661
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>I. The majority of accidents (563,801 cases) are classified as Slight, showing that while road accidents are common, most are not life-threatening.</h3>
# <h3>II. Fatal accidents (8,661 cases) make up only about 1% of all accidents, which suggests that although accidents are frequent, road safety measures and emergency responses help prevent most from becoming deadly.</h3>

# %% [markdown]
# <h2>2. What is the average number of casualties per accident?</h2>

# %%
accidents['Number_of_Casualties'].mean()
# Out:
# np.float64(1.357040257068864)

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>III. Most accidents involve only one person injured, since the average is close to 1. This suggests that single-vehicle or low-impact accidents are common.</h3>
# <h3>IV. The fact that the mean is slightly above 1 indicates that while most cases involve just one casualty, there are also some multi-casualty accidents that raise the average.</h3>

# %% [markdown]
# <h2>3. What is the maximum number of casualties in a single accident?</h2>

# %%
accidents['Number_of_Casualties'].value_counts()
# Out:
# Number_of_Casualties
# 1     504041
# 2     107971
# 3      30776
# 4      11156
# 5       4123
# 6       1525
# 7        539
# 8        214
# 9        112
# 10        58
# 11        36
# 13        24
# 12        21
# 14        13
# 15        11
# 17         8
# 19         7
# 16         7
# 18         6
# 22         5
# 21         4
# 29         3
# 40         2
# 28         2
# 24         2
# 27         2
# 42         2
# 25         1
# 32         1
# 68         1
# 45         1
# 62         1
# 47         1
# 48         1
# 26         1
# 43         1
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>V. The vast majority of accidents (over 500,000 cases) involve only 1 casualty, confirming that most incidents are minor and isolated.</h3>
# <h3>VI. Rare but extreme cases exist, with up to 67 casualties in a single accident, likely representing major multi-vehicle crashes or bus accidents. These outliers significantly impact safety policies and emergency preparedness.</h3>

# %% [markdown]
# <h2>4. How many accidents happened per year?</h2>

# %%
accidents['Year'].value_counts()
# Out:
# Year
# 2019    182115
# 2020    170591
# 2021    163554
# 2022    144419
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>VII. There is a steady decline in accidents from 2019 (182,115) to 2022 (144,419), showing a downward trend in road incidents.</h3>
# <h3>VIII. The sharp drop in 2020 and 2021 likely reflects the COVID-19 lockdowns, when reduced travel led to fewer accidents.</h3>

# %% [markdown]
# <h2>5. Which month has the highest number of accidents?</h2>

# %%
accidents['Month'].value_counts()
# Out:
# Month
# 11    60424
# 10    59580
# 7     57445
# 6     56481
# 9     56455
# 5     56352
# 3     54086
# 8     53913
# 1     52872
# 12    51836
# 4     51744
# 2     49491
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>IX. November (60,424 accidents) has the highest number of accidents, followed closely by October and July, which may be linked to shorter daylight hours and wetter road conditions in autumn.</h3>
# <h3>X. The lowest number of accidents occurs in February (49,491), possibly due to fewer travel days (shorter month) and reduced mobility in winter.</h3>

# %% [markdown]
# <h2>6. Which day of the week has the most accidents?</h2>

# %%
accidents['DayOfWeek'].value_counts() # Monday = 0, Sunday = 6
# Out:
# DayOfWeek
# 5    107178
# 2     99558
# 3     99511
# 4     97900
# 1     94550
# 6     89302
# 0     72680
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>XI. Friday (107,178 accidents) has the highest number of accidents, likely due to end-of-week traffic, rush hours, and social activities.</h3>
# <h3>XII. Sunday (72,680 accidents) has the lowest number, reflecting reduced commuting and lighter traffic compared to weekdays.</h3>

# %% [markdown]
# <h2>7. Which district area has the highest number of accidents?</h2>

# %%
accidents['District Area'].value_counts()
# Out:
# District Area
# Birmingham            13491
# Leeds                  8898
# Manchester             6720
# Bradford               6212
# Sheffield              5710
#                       ...
# Berwick-upon-Tweed      153
# Teesdale                142
# Shetland Islands        133
# Orkney Islands          117
# Clackmannanshire         91
# Name: count, Length: 422, dtype: int64

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>XIII. Birmingham (13,491 accidents) has the highest number, which is expected since it’s a large, densely populated urban area with heavy traffic.</h3>

# %% [markdown]
# <h2>8. Which district area has the highest number of casualties?</h2>

# %%
accidents.groupby('District Area')['Number_of_Casualties'].sum().idxmax()
# Out:
# 'Birmingham'

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>XIV. Birmingham has the highest number of casualties</h3>

# %% [markdown]
# <h2>9. Are accidents more common in urban or rural areas?</h2>

# %%
accidents['Urban_or_Rural_Area'].value_counts()
# Out:
# Urban_or_Rural_Area
# Urban          421663
# Rural          238990
# unaccounted        15
# Unallocated        11
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>XV. The majority of accidents happen in urban areas (421,663 cases), almost double the number in rural areas (238,990). This is expected due to higher traffic density, more intersections, and congestion in cities.</h3>

# %% [markdown]
# <h2>10. Are urban or rural areas more likely to have serious/fatal accidents?</h2>

# %%
urban = accidents[accidents['Urban_or_Rural_Area'] == 'Urban']

# %%
urban[urban['Accident_Severity'] == 'Serious'].value_counts().sum()
# Out:
# np.int64(50902)

# %%
urban[urban['Accident_Severity'] == 'Fatal'].value_counts().sum()
# Out:
# np.int64(3060)

# %%
rural = accidents[accidents['Urban_or_Rural_Area'] == 'Rural']

# %%
rural[rural['Accident_Severity'] == 'Serious'].value_counts().sum()
# Out:
# np.int64(37312)

# %%
rural[rural['Accident_Severity'] == 'Fatal'].value_counts().sum()
# Out:
# np.int64(5601)

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>XVI. Rural areas have 2.5x higher fatality rates - 15% of serious accidents are fatal in rural areas vs only 6% in urban areas, likely due to slower emergency response times and higher speeds.</h3>

# %% [markdown]
# <h2>11. How does road surface condition (dry, wet, icy, etc.) affect accident frequency?</h2>

# %%
accidents['Road_Surface_Conditions'].value_counts()
# Out:
# Road_Surface_Conditions
# Dry                     447821
# Wet or damp             186708
# Frost or ice             18517
# Snow                      5890
# Flood over 3cm. deep      1017
# unaccounted                726
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>XVII. Dry roads have the most accidents (447K), but wet conditions are surprisingly high at 187K - suggesting that even moderate weather significantly increases crash risk, while extreme conditions like ice (18.5K) and snow (5.8K) have fewer total accidents likely due to reduced traffic volume during those conditions.</h3>

# %% [markdown]
# <h2>12. Which road type (single carriageway, dual, roundabout, etc.) has the most accidents?</h2>

# %%
accidents['Road_Type'].value_counts()
# Out:
# Road_Type
# Single carriageway    492143
# Dual carriageway       99424
# Roundabout             43992
# One way street         13559
# Slip road               7041
# unaccounted             4520
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>XVIII. Single carriageways have the most accidents (492K), followed by dual carriageways (99K) and roundabouts (44K). This likely reflects that single carriageways are the most common road type and often have head-on collision risks, while roundabouts have fewer accidents despite being complex intersections.</h3>

# %% [markdown]
# <h2>13. Do accidents occur more frequently on wet or dry roads?</h2>

# %%
accidents[accidents['Road_Surface_Conditions'] == 'Dry'].value_counts().sum()
# Out:
# np.int64(447821)

# %%
accidents[accidents['Road_Surface_Conditions'] == 'Wet or damp'].value_counts().sum()
# Out:
# np.int64(186708)

# %% [markdown]
# <h3>XIX. Dry roads have significantly more accidents (447K) than wet roads (187K) - about 2.4 times more. However, this likely reflects that dry conditions are much more common than wet conditions, so the accident rate per mile driven might actually be higher in wet conditions.</h3>

# %% [markdown]
# <h2>14. How does weather condition (rain, snow, fog, fine) affect accident severity?</h2>

# %%
accidents.groupby(['Weather_Conditions', 'Accident_Severity']).size()
# Out:
# Weather_Conditions     Accident_Severity
# Fine + high winds      Fatal                   175
#                        Serious                1245
#                        Slight                 7134
# Fine no high winds     Fatal                  7207
#                        Serious               73285
#                        Slight               454521
# Fog or mist            Fatal                    82
#                        Serious                 483
#                        Slight                 2963
# Other                  Fatal                   165
#                        Serious                1801
#                        Slight                15184
# Raining + high winds   Fatal                   145
#                        Serious                1261
#                        Slight                 8209
# Raining no high winds  Fatal                   848
#                        Serious                9468
#                        Slight                69380
# Snowing + high winds   Fatal                     3
#                        Serious                 109
#                        Slight                  773
# Snowing no high winds  Fatal                    36
#                        Serious                 565
#                        Slight                 5637
# dtype: int64

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>XX. Fine weather conditions dominate accident statistics - "Fine no high winds" accounts for the vast majority of accidents across all severity levels (over 500K total), while adverse weather like rain, snow, and fog have much lower absolute numbers but may have higher accident rates per exposure time.</h3>

# %% [markdown]
# <h2>15.	Are more accidents reported in daylight or darkness?</h2>

# %%
accidents['Light_Conditions'].value_counts()
# Out:
# Light_Conditions
# Daylight                       484880
# Darkness - lights lit          129335
# Darkness - no lighting          37437
# Darkness - lighting unknown      6484
# Darkness - lights unlit          2543
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>XXI. Daylight has significantly more accidents (485K) than all darkness conditions combined (~175K total). However, this likely reflects higher traffic volumes during daylight hours rather than darkness being safer - the accident rate per vehicle mile traveled might actually be higher in dark conditions.</h3>

# %% [markdown]
# <h2>16. Do accidents at night tend to be more severe than in the day?</h2>

# %%
accidents.groupby('Light_Conditions')['Accident_Severity'].value_counts()
# Out:
# Light_Conditions             Accident_Severity
# Darkness - lighting unknown  Slight                 5622
#                              Serious                 794
#                              Fatal                    68
# Darkness - lights lit        Slight               108345
#                              Serious               19130
#                              Fatal                  1860
# Darkness - lights unlit      Slight                 2138
#                              Serious                 360
#                              Fatal                    45
# Darkness - no lighting       Slight                28651
#                              Serious                7174
#                              Fatal                  1612
# Daylight                     Slight               419045
#                              Serious               60759
#                              Fatal                  5076
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>XXII. Yes, night accidents are more severe. Darkness conditions have higher fatality rates: "Darkness - no lighting" has a 4.3% fatal rate (1,612/37,437 total) compared to daylight's 1.2% fatal rate (5,076/419,045+60,759+5,076 total). This suggests reduced visibility at night leads to more deadly crashes.</h3>

# %% [markdown]
# <h2>17.	What is the average number of vehicles involved in accidents?</h2>

# %%
accidents['Number_of_Vehicles'].mean()
# Out:
# np.float64(1.8312554205597575)

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>XXIII. The average number of vehicles involved in accidents is 1.83, meaning most accidents involve just 1-2 vehicles, with single-vehicle accidents and two-vehicle collisions being the most common types.</h3>

# %% [markdown]
# <h2>18.	Which vehicle type is involved in the most accidents?</h2>

# %%
accidents['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# Car                                      497992
# Van / Goods 3.5 tonnes mgw or under       34160
# Bus or coach (17 or more pass seats)      25878
# Motorcycle over 500cc                     25657
# Goods 7.5 tonnes mgw and over             17307
# Motorcycle 125cc and under                15269
# Taxi/Private hire car                     13294
# Motorcycle over 125cc and up to 500cc      7656
# Motorcycle 50cc and under                  7603
# Goods over 3.5t. and under 7.5t            6096
# Other vehicle                              5637
# Minibus (8 - 16 passenger seats)           1976
# Agricultural vehicle                       1947
# Pedal cycle                                 197
# Data missing or out of range                  6
# Ridden horse                                  4
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>XXIV. Cars dominate accident statistics with 498K incidents, far exceeding all other vehicle types. Vans/goods vehicles (34K), buses/coaches (26K), and motorcycles over 500cc (26K) follow as distant seconds, reflecting cars' much higher road usage.</h3>

# %% [markdown]
# <h2>19. What combination of weather + light condition results in the highest accident counts?</h2>

# %%
accidents.groupby(['Weather_Conditions', 'Light_Conditions']).size()
# Out:
# Weather_Conditions     Light_Conditions
# Fine + high winds      Darkness - lighting unknown        59
#                        Darkness - lights lit            1852
#                        Darkness - lights unlit            51
#                        Darkness - no lighting            796
#                        Daylight                         5796
# Fine no high winds     Darkness - lighting unknown      5333
#                        Darkness - lights lit           93958
#                        Darkness - lights unlit          1745
#                        Darkness - no lighting          25251
#                        Daylight                       408726
# Fog or mist            Darkness - lighting unknown        65
#                        Darkness - lights lit             921
#                        Darkness - lights unlit            37
#                        Darkness - no lighting            862
#                        Daylight                         1643
# Other                  Darkness - lighting unknown       186
#                        Darkness - lights lit            4803
#                        Darkness - lights unlit           143
#                        Darkness - no lighting           1915
#                        Daylight                        10103
# Raining + high winds   Darkness - lighting unknown       111
#                        Darkness - lights lit            3066
#                        Darkness - lights unlit            73
#                        Darkness - no lighting           1423
#                        Daylight                         4942
# Raining no high winds  Darkness - lighting unknown       621
#                        Darkness - lights lit           22666
#                        Darkness - lights unlit           459
#                        Darkness - no lighting           6208
#                        Daylight                        49742
# Snowing + high winds   Darkness - lighting unknown        15
#                        Darkness - lights lit             241
#                        Darkness - lights unlit             5
#                        Darkness - no lighting            171
#                        Daylight                          453
# Snowing no high winds  Darkness - lighting unknown        94
#                        Darkness - lights lit            1828
#                        Darkness - lights unlit            30
#                        Darkness - no lighting            811
#                        Daylight                         3475
# dtype: int64

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h3>XXV. "Fine no high winds + Daylight" has the highest accident count at 358,636, which makes sense as this represents the most common driving conditions when traffic volume is highest. The combination of good weather and daylight hours when most people are on the road naturally leads to the most total accidents.</h3>

# %% [markdown]
# <h1>20. </h1>

# %%
x = accidents['Accident_Severity'].value_counts()
x.plot(kind='pie',
      title='Accident Severity',
      autopct='%.1f%%')
plt.show()

# %% [markdown]
# <h2>INSIGHT</h2>
# <H3>XXVI. 85% of accidents are slight, but 1 in 7 still result in serious injury or death - suggesting that while most accidents are minor, the risk of severe outcomes remains significant.</H3>

# %% [markdown]
# <h1>21.</h1>

# %%
y = accidents.groupby(['Year', 'Accident_Severity']).size().unstack()
y.plot(kind='bar', 
       stacked=True, 
       figsize=(10,6),
      title='Accident Severity')
plt.show()

# %% [markdown]
# <H2>INSIGHT</H2>
# <H3>XXVII. Accident frequency is declining over time - total accidents dropped from ~180k in 2019 to ~145k in 2022, showing a consistent downward trend across all severity levels.</H3>

# %% [markdown]
# <h1>22.</h1>

# %%
x = accidents['Road_Surface_Conditions'].value_counts()
x.plot(kind='pie',
      title='Road_Surface_Conditions')
plt.show()

# %% [markdown]
# <H2>INSIGHT</H2>
# <H3>XXVIII. Dry road conditions dominate accident data - approximately 70% of accidents occur on dry roads, suggesting that poor weather/road conditions aren't the primary factor in most crashes.</H3>

# %% [markdown]
# <h1>23. </h1>

# %%
y = accidents.groupby(['Accident Date', 'Number_of_Casualties']).size().unstack()
y.plot(stacked=True, 
       figsize=(10,6),
      title='Accident Severity')
plt.show()

# %% [markdown]
# <H2>INSIGHT</H2>
# <H3>XXIX. Daily accident counts show consistent patterns with notable COVID-19 impact - there's a clear drop in accidents during early 2020 lockdowns, followed by gradual recovery, with single-casualty accidents (brown) dominating throughout the timeline.</H3>

# %% [markdown]
# <h1>24.</h1>

# %%
x = accidents['Weather_Conditions'].value_counts()
x.plot(kind='pie',
      title='Weather_Conditions',
      autopct='%.1f%%')
plt.show()

# %% [markdown]
# <H2>INSIGHT</H2>
# <H3>XXX. Good weather dominates accident statistics - over 80% of accidents occur in fine weather with no high winds, reinforcing that weather conditions are not the main cause of most traffic accidents.</H3>

# %% [markdown]
# <hr>
# <h1>Using District Area to make a comparison to a general result</h1>

# %% [markdown]
# <h1>DISTRICT #1</h1>

# %%
# District
district1 = accidents[accidents['District Area'] == 'Cornwall']

monthly_district1 = district1.groupby(['Year', 'Month']).size()

monthly_district1 = monthly_district1.unstack(level=0)

monthly_district1.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in London by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# Per Year, Month, Day
accidents_per_year = district1['Year'].value_counts().sort_index()
accidents_per_month = district1['Month'].value_counts().sort_index()
accidents_per_day = district1['DayOfWeek'].value_counts().sort_index()

accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)

accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()


day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday       293
# Tuesday      356
# Wednesday    385
# Thursday     413
# Friday       376
# Saturday     419
# Sunday       364
# Name: count, dtype: int64

# %%
# Severity
severity_district1  = district1['Accident_Severity'].value_counts()

plt.pie(severity_district1,
        labels = severity_district1.index,
        autopct = '%1.1f%%',
        startangle = 90)
plt.gcf().set_size_inches(10,7)
plt.title('Accident Severity Distribution')
plt.show()

severity_2021_district1 = district1[district1['Year'] == 2021]

district1_2021 = severity_2021_district1['Accident_Severity'].value_counts()

plt.pie(district1_2021,
        labels = district1_2021.index,
        autopct = '%1.1f%%',
        startangle = 90)
plt.gcf().set_size_inches(10,7)
plt.title('Accident Severity Distribution')
plt.show()

# %% [markdown]
# <h1>HEATMAP FOR CORNWALL DISTRICT</h1>

# %%
cornwall_accidents = accidents[accidents['District Area']== 'Cornwall']

cornwall_fatal = cornwall_accidents[cornwall_accidents['Accident_Severity'] == 'Fatal']

locations  = list(zip(cornwall_fatal['Latitude'],cornwall_fatal['Longitude']))

Dando1 = folium.Map(location=[cornwall_fatal['Latitude'].mean(), cornwall_fatal['Longitude'].mean()], zoom_start=10)

HeatMap(locations).add_to(Dando1)
Dando1.save('accident_heatmap.html')
Dando1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffaeceee689db04ba639571156abfe5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffaeceee689db04ba639571156abfe5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ffaeceee689db04ba639571156abfe5b = L.map(
#                 &quot;map_ffaeceee689db04ba639571156abfe5b&quot;,
#                 {
#                     center: [50.33581786046512, -4.899710534883721],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b2b11d07797b6039f8afd51b9975eef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b2b11d07797b6039f8afd51b9975eef.addTo(map_ffaeceee689db04ba639571156abfe5b);
#
#
#             var heat_map_fcc94723ae428eb1b0add1fb7567c9fd = L.heatLayer(
#                 [[50.149749, -5.2502], [50.131438, -5.226145], [50.143676, -5.368501], [50.225699, -5.384799], [50.170838, -5.445352], [50.342872, -4.609025], [50.595838, -4.476026], [50.589759, -4.528693], [50.413463, -4.330522], [50.409444, -4.360305], [50.416379, -4.255633], [50.363944, -4.314876], [50.396511, -4.793643], [50.461332, -4.923162], [50.334039, -4.951879], [50.155926, -5.100093], [50.206246, -5.115689], [50.296798, -5.117111], [50.275747, -5.021825], [50.222644, -5.104699], [50.217816, -5.318201], [50.103386, -5.314897], [50.119146, -5.241129], [50.099786, -5.270591], [50.170938, -5.137342], [50.149979, -5.656537], [50.199263, -5.396663], [50.490174, -4.693556], [50.432773, -4.437229], [50.595662, -4.475876], [50.608876, -4.446462], [50.346097, -4.219971], [50.826253, -4.506662], [50.594029, -4.83161], [50.428435, -4.812702], [50.420664, -4.832657], [50.331304, -4.811878], [50.339224, -4.80054], [50.433176, -4.96579], [50.429547, -4.938666], [50.208284, -5.123532], [50.250337, -5.061183], [50.342677, -4.715701]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_fcc94723ae428eb1b0add1fb7567c9fd.addTo(map_ffaeceee689db04ba639571156abfe5b);
#
#
#             tile_layer_0b2b11d07797b6039f8afd51b9975eef.addTo(map_ffaeceee689db04ba639571156abfe5b);
#
#
#             heat_map_fcc94723ae428eb1b0add1fb7567c9fd.addTo(map_ffaeceee689db04ba639571156abfe5b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <H2>INSIGHT</H2>
# <H3>XXXI. There is a clear hotspot of fatal accidents in the northeastern part of Cornwall, indicating a high-risk area where targeted road safety measures may be needed.</H3>

# %% [markdown]
# <h1>DISTRICT #2</h1>

# %%
# District
district2 = accidents[accidents['District Area'] == 'Wiltshire']

monthly_district2 = district2.groupby(['Year', 'Month']).size()

monthly_district2 = monthly_district2.unstack(level=0)

monthly_district2.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in London by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# Per Year, Month, Day
accidents_per_year = district2['Year'].value_counts().sort_index()
accidents_per_month = district2['Month'].value_counts().sort_index()
accidents_per_day = district2['DayOfWeek'].value_counts().sort_index()

accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)

accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()


day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday       183
# Tuesday      226
# Wednesday    233
# Thursday     237
# Friday       223
# Saturday     272
# Sunday       216
# Name: count, dtype: int64

# %%
# Severity
severity_district2  = district2['Accident_Severity'].value_counts()

plt.pie(severity_district2,
        labels = severity_district2.index,
        autopct = '%1.1f%%',
        startangle = 90)
plt.gcf().set_size_inches(10,7)
plt.title('Accident Severity Distribution')
plt.show()

severity_2022_district2 = district2[district2['Year'] == 2022]

district2_2022 = severity_2022_district2['Accident_Severity'].value_counts()

plt.pie(district2_2022,
        labels = district2_2022.index,
        autopct = '%1.1f%%',
        startangle = 90)
plt.gcf().set_size_inches(10,7)
plt.title('Accident Severity Distribution')
plt.show()

# %% [markdown]
# <h1>HEATMAP FOR WILTSHIRE DISTRICT</h1>

# %%
wiltshire_accidents = accidents[accidents['District Area']== 'Wiltshire']

wiltshire_fatal = wiltshire_accidents[wiltshire_accidents['Accident_Severity'] == 'Fatal']

locations  = list(zip(wiltshire_fatal['Latitude'],wiltshire_fatal['Longitude']))

Dando2 = folium.Map(location=[wiltshire_fatal['Latitude'].mean(), wiltshire_fatal['Longitude'].mean()], zoom_start=10)

HeatMap(locations).add_to(Dando2)
Dando2.save('accident_heatmap.html')
Dando2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42e8f49125bb3ed905e374d970ec39ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42e8f49125bb3ed905e374d970ec39ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42e8f49125bb3ed905e374d970ec39ed = L.map(
#                 &quot;map_42e8f49125bb3ed905e374d970ec39ed&quot;,
#                 {
#                     center: [51.297523209302334, -1.9495116744186047],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebba769166830d52fb87c5dbca687d9e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ebba769166830d52fb87c5dbca687d9e.addTo(map_42e8f49125bb3ed905e374d970ec39ed);
#
#
#             var heat_map_38d62115610906ce57fc9c0099742a89 = L.heatLayer(
#                 [[51.373744, -2.144929], [51.432816, -2.207692], [51.415882, -2.266717], [51.482528, -1.842566], [51.255152, -1.619941], [51.180295, -1.734581], [51.177045, -1.823437], [51.171575, -1.779116], [51.179659, -1.827147], [51.438655, -2.047589], [51.514638, -2.037437], [51.209909, -2.205686], [51.151368, -2.028277], [51.066203, -1.788752], [51.050205, -1.792962], [51.06699, -2.170229], [51.088126, -2.167308], [51.03649, -1.892288], [51.654446, -1.938966], [51.281465, -2.071371], [51.369332, -2.037031], [51.552969, -1.8729], [51.322968, -2.237476], [51.361444, -2.128516], [51.356171, -2.094609], [51.434902, -2.197056], [51.460234, -1.846816], [51.449006, -1.855776], [51.511178, -1.628334], [51.268235, -1.663552], [51.251618, -1.786184], [51.178095, -1.756911], [51.159544, -1.951062], [51.14975, -1.977236], [51.142344, -1.775825], [51.145531, -1.859011], [51.465189, -1.984997], [51.50037, -2.125737], [51.083855, -1.803805], [51.101174, -1.839294], [51.568192, -2.099232], [51.364784, -1.88362], [51.369422, -2.037031]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_38d62115610906ce57fc9c0099742a89.addTo(map_42e8f49125bb3ed905e374d970ec39ed);
#
#
#             tile_layer_ebba769166830d52fb87c5dbca687d9e.addTo(map_42e8f49125bb3ed905e374d970ec39ed);
#
#
#             heat_map_38d62115610906ce57fc9c0099742a89.addTo(map_42e8f49125bb3ed905e374d970ec39ed);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <H2>INSIGHT</H2>
# <H3>XXXII. The heatmap for Wiltshire District shows that fatal accidents are highly concentrated around the Salisbury area and along major road routes near Devizes, suggesting these are critical zones for road safety attention.</H3>

# %% [markdown]
# <h1>DISTRICT #3</h1>

# %%
# District
district3 = accidents[accidents['District Area'] == 'Shropshire']

monthly_district3 = district3.groupby(['Year', 'Month']).size()

monthly_district3 = monthly_district3.unstack(level=0)

monthly_district3.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in London by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# Per Year, Month, Day
accidents_per_year = district3['Year'].value_counts().sort_index()
accidents_per_month = district3['Month'].value_counts().sort_index()
accidents_per_day = district3['DayOfWeek'].value_counts().sort_index()

accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)

accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()


day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday       193
# Tuesday      199
# Wednesday    183
# Thursday     185
# Friday       174
# Saturday     225
# Sunday       184
# Name: count, dtype: int64

# %%
# Severity
severity_district3  = district3['Accident_Severity'].value_counts()

plt.pie(severity_district3,
        labels = severity_district3.index,
        autopct = '%1.1f%%',
        startangle = 90)
plt.gcf().set_size_inches(10,7)
plt.title('Accident Severity Distribution')
plt.show()

severity_2022_district3 = district3[district3['Year'] == 2022]

district3_2022 = severity_2022_district3['Accident_Severity'].value_counts()

plt.pie(district3_2022,
        labels = district3_2022.index,
        autopct = '%1.1f%%',
        startangle = 90)
plt.gcf().set_size_inches(10,7)
plt.title('Accident Severity Distribution')
plt.show()

# %% [markdown]
# <h1>HEATMAP FOR SHROPSHIRE DISTRICT</h1>

# %%
shropshire_accidents = accidents[accidents['District Area']== 'Shropshire']

shropshire_fatal = shropshire_accidents[shropshire_accidents['Accident_Severity'] == 'Fatal']

locations  = list(zip(shropshire_fatal['Latitude'],shropshire_fatal['Longitude']))

Dando3 = folium.Map(location=[shropshire_fatal['Latitude'].mean(), shropshire_fatal['Longitude'].mean()], zoom_start=10)

HeatMap(locations).add_to(Dando3)
Dando3.save('accident_heatmap.html')
Dando3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34210013e64f9192d1f433385078b659 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34210013e64f9192d1f433385078b659&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34210013e64f9192d1f433385078b659 = L.map(
#                 &quot;map_34210013e64f9192d1f433385078b659&quot;,
#                 {
#                     center: [52.69262328947369, -2.6767433947368424],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_33144ea89781c2b9d95df05e278359af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_33144ea89781c2b9d95df05e278359af.addTo(map_34210013e64f9192d1f433385078b659);
#
#
#             var heat_map_73f02c55e416c33a0b3484d9f6644c61 = L.heatLayer(
#                 [[52.714319, -2.806303], [52.312469, -2.705245], [52.852996, -2.481712], [52.905063, -2.885075], [52.707963, -2.732919], [52.864233, -3.052399], [52.750491, -2.87779], [52.542895, -2.816872], [52.825248, -2.738304], [52.867909, -3.043277], [52.84188, -3.038496], [52.376809, -2.500018], [52.879843, -2.551107], [52.680711, -2.927276], [52.533758, -2.412165], [52.548076, -2.281049], [52.557599, -2.319313], [52.527527, -2.393829], [52.527527, -2.393976], [52.509839, -2.38704], [52.780472, -2.663269], [52.365011, -2.699032], [52.928235, -3.042942], [52.895243, -2.934822], [52.987719, -2.688784], [52.71626, -2.837576], [52.849245, -3.029019], [52.736856, -2.666013], [52.457018, -2.751998], [52.888137, -2.546159], [52.809918, -2.547997], [52.670589, -2.699167], [52.912831, -2.641495], [52.468487, -2.978455], [52.676237, -2.389248], [52.67791, -2.399765], [52.620694, -2.355962], [52.551668, -2.500381]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_73f02c55e416c33a0b3484d9f6644c61.addTo(map_34210013e64f9192d1f433385078b659);
#
#
#             tile_layer_33144ea89781c2b9d95df05e278359af.addTo(map_34210013e64f9192d1f433385078b659);
#
#
#             heat_map_73f02c55e416c33a0b3484d9f6644c61.addTo(map_34210013e64f9192d1f433385078b659);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <H2>INSIGHT</H2>
# <H3>XXXIII. The heatmap for Shropshire District shows strong fatal accident hotspots near Shrewsbury and Market Drayton, indicating these areas as key high-risk zones for severe road incidents.</H3>

# %% [markdown]
# <h1>DISTRICT #4</h1>

# %%
# District
district4 = accidents[accidents['District Area'] == 'Renfrewshire']

monthly_district4 = district4.groupby(['Year', 'Month']).size()

monthly_district4 = monthly_district4.unstack(level=0)

monthly_district4.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in London by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# Per Year, Month, Day
accidents_per_year = district4['Year'].value_counts().sort_index()
accidents_per_month = district4['Month'].value_counts().sort_index()
accidents_per_day = district4['DayOfWeek'].value_counts().sort_index()

accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)

accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()


day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday       126
# Tuesday      150
# Wednesday    189
# Thursday     167
# Friday       171
# Saturday     153
# Sunday       148
# Name: count, dtype: int64

# %%
# Severity
severity_district4  = district4['Accident_Severity'].value_counts()

plt.pie(severity_district4,
        labels = severity_district4.index,
        autopct = '%1.1f%%',
        startangle = 90)
plt.gcf().set_size_inches(10,7)
plt.title('Accident Severity Distribution')
plt.show()

severity_2019_district4 = district4[district4['Year'] == 2019]

district4_2019 = severity_2019_district4['Accident_Severity'].value_counts()

plt.pie(district4_2019,
        labels = district4_2019.index,
        autopct = '%1.1f%%',
        startangle = 90)
plt.gcf().set_size_inches(10,7)
plt.title('Accident Severity Distribution')
plt.show()

# %% [markdown]
# <h1>HEATMAP FOR RENFREWSHIRE DISTRICT</h1>

# %%
renfrewshire_accidents = accidents[accidents['District Area']== 'Renfrewshire']

renfrewshire_fatal = renfrewshire_accidents[renfrewshire_accidents['Accident_Severity'] == 'Fatal']

locations  = list(zip(renfrewshire_fatal['Latitude'],renfrewshire_fatal['Longitude']))

Dando4 = folium.Map(location=[renfrewshire_fatal['Latitude'].mean(), renfrewshire_fatal['Longitude'].mean()], zoom_start=10)

HeatMap(locations).add_to(Dando4)
Dando4.save('accident_heatmap.html')
Dando4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d1778737eeb315f3c1572a702da3906 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d1778737eeb315f3c1572a702da3906&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d1778737eeb315f3c1572a702da3906 = L.map(
#                 &quot;map_6d1778737eeb315f3c1572a702da3906&quot;,
#                 {
#                     center: [55.84531211764706, -4.4612151764705885],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bdfe7834eaac3fc31c3fe80874c59cc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7bdfe7834eaac3fc31c3fe80874c59cc.addTo(map_6d1778737eeb315f3c1572a702da3906);
#
#
#             var heat_map_457d2ce7282d30871166a1d5158543a3 = L.heatLayer(
#                 [[55.849795, -4.430355], [55.83953, -4.462938], [55.81884, -4.418526], [55.859473, -4.454452], [55.837571, -4.479904], [55.79377, -4.598694], [55.844582, -4.439455], [55.859176, -4.41496], [55.838913, -4.439738], [55.842412, -4.431012], [55.833538, -4.397719], [55.875986, -4.391862], [55.914182, -4.50496], [55.85188, -4.518845], [55.801339, -4.589304], [55.82623, -4.389924], [55.883089, -4.47801]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_457d2ce7282d30871166a1d5158543a3.addTo(map_6d1778737eeb315f3c1572a702da3906);
#
#
#             tile_layer_7bdfe7834eaac3fc31c3fe80874c59cc.addTo(map_6d1778737eeb315f3c1572a702da3906);
#
#
#             heat_map_457d2ce7282d30871166a1d5158543a3.addTo(map_6d1778737eeb315f3c1572a702da3906);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <H2>INSIGHT</H2>
# <H3>XXXIV. Renfrewshire District shows a major concentration of fatal accidents near Paisley, suggesting this urban area and its surrounding road network are particularly high-risk.</H3>

# %% [markdown]
# <h1>DISTRICT #5</h1>

# %%
# District
district5 = accidents[accidents['District Area'] == 'Northumberland']

monthly_district5 = district5.groupby(['Year', 'Month']).size()

monthly_district5 = monthly_district5.unstack(level=0)

monthly_district5.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in London by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# Per Year, Month, Day
accidents_per_year = district5['Year'].value_counts().sort_index()
accidents_per_month = district5['Month'].value_counts().sort_index()
accidents_per_day = district5['DayOfWeek'].value_counts().sort_index()

accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)

accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()


day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday       208
# Tuesday      199
# Wednesday    248
# Thursday     190
# Friday       234
# Saturday     254
# Sunday       243
# Name: count, dtype: int64

# %%
# Severity
severity_district5  = district5['Accident_Severity'].value_counts()

plt.pie(severity_district5,
        labels = severity_district5.index,
        autopct = '%1.1f%%',
        startangle = 90)
plt.gcf().set_size_inches(10,7)
plt.title('Accident Severity Distribution')
plt.show()

severity_2021_district5 = district5[district5['Year'] == 2021]

district5_2021 = severity_2021_district5['Accident_Severity'].value_counts()

plt.pie(district5_2021,
        labels = district5_2021.index,
        autopct = '%1.1f%%',
        startangle = 90)
plt.gcf().set_size_inches(10,7)
plt.title('Accident Severity Distribution')
plt.show()

# %% [markdown]
# <h1>HEATMAP FOR NORTHUMBERLAND DISTRICT</h1>

# %%
northumberland_accidents = accidents[accidents['District Area']== 'Northumberland']

northumberland_fatal = northumberland_accidents[northumberland_accidents['Accident_Severity'] == 'Fatal']

locations  = list(zip(northumberland_fatal['Latitude'],northumberland_fatal['Longitude']))

Dando5 = folium.Map(location=[northumberland_fatal['Latitude'].mean(), northumberland_fatal['Longitude'].mean()], zoom_start=10)

HeatMap(locations).add_to(Dando5)
Dando5.save('accident_heatmap.html')
Dando5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbbe2f195780fb80c596e931cea40087 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbbe2f195780fb80c596e931cea40087&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbbe2f195780fb80c596e931cea40087 = L.map(
#                 &quot;map_bbbe2f195780fb80c596e931cea40087&quot;,
#                 {
#                     center: [55.18259545833334, -1.8533671666666667],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c519e3772d8bd2746b8e01b89c57881 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5c519e3772d8bd2746b8e01b89c57881.addTo(map_bbbe2f195780fb80c596e931cea40087);
#
#
#             var heat_map_67bf752a14e582e2c93e6bf9b0f5f661 = L.heatLayer(
#                 [[55.205844, -2.188679], [55.186967, -1.539159], [55.422374, -1.705314], [55.401974, -1.853426], [55.011609, -1.952116], [55.110614, -1.826749], [55.274784, -1.725926], [55.713857, -1.977522], [54.978145, -2.313384], [55.178315, -1.669746], [55.012776, -1.948987], [54.961283, -1.842853], [55.014579, -2.036559], [55.308046, -1.922773], [55.769118, -2.002674], [54.998795, -1.876003], [55.370923, -1.816462], [55.009708, -1.924285], [55.161805, -1.538978], [55.084088, -1.475801], [55.127177, -1.507856], [55.168075, -1.857582], [54.993194, -2.023879], [54.918241, -1.954099]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_67bf752a14e582e2c93e6bf9b0f5f661.addTo(map_bbbe2f195780fb80c596e931cea40087);
#
#
#             tile_layer_5c519e3772d8bd2746b8e01b89c57881.addTo(map_bbbe2f195780fb80c596e931cea40087);
#
#
#             heat_map_67bf752a14e582e2c93e6bf9b0f5f661.addTo(map_bbbe2f195780fb80c596e931cea40087);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <H2>INSIGHT</H2>
# <H3>XXXV. Northumberland District shows a strong fatal accident hotspot near Prudhoe, indicating this area as a key location where road safety improvements may be most needed.</H3>

# %% [markdown]
# <h1>DISTRICT #6</h1>

# %%
# District
district6 = accidents[accidents['District Area'] == 'Stirling']

monthly_district6 = district6.groupby(['Year', 'Month']).size()

monthly_district6 = monthly_district6.unstack(level=0)

monthly_district6.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in London by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# Per Year, Month, Day
accidents_per_year = district6['Year'].value_counts().sort_index()
accidents_per_month = district6['Month'].value_counts().sort_index()
accidents_per_day = district6['DayOfWeek'].value_counts().sort_index()

accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)

accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()


day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday       119
# Tuesday      119
# Wednesday    122
# Thursday     104
# Friday       100
# Saturday     129
# Sunday       127
# Name: count, dtype: int64

# %%
# Severity
severity_district6  = district6['Accident_Severity'].value_counts()

plt.pie(severity_district6,
        labels = severity_district6.index,
        autopct = '%1.1f%%',
        startangle = 90)
plt.gcf().set_size_inches(10,7)
plt.title('Accident Severity Distribution')
plt.show()

severity_2019_district6 = district6[district6['Year'] == 2019]

district6_2019 = severity_2019_district6['Accident_Severity'].value_counts()

plt.pie(district6_2019,
        labels = district6_2019.index,
        autopct = '%1.1f%%',
        startangle = 90)
plt.gcf().set_size_inches(10,7)
plt.title('Accident Severity Distribution')
plt.show()

# %% [markdown]
# <h1>HEATMAP FOR STIRLING DISTRICT</h1>

# %%
stirling_accidents = accidents[accidents['District Area']== 'Stirling']

stirling_fatal = stirling_accidents[stirling_accidents['Accident_Severity'] == 'Fatal']

locations  = list(zip(stirling_fatal['Latitude'],stirling_fatal['Longitude']))

Dando6 = folium.Map(location=[stirling_fatal['Latitude'].mean(), stirling_fatal['Longitude'].mean()], zoom_start=10)

HeatMap(locations).add_to(Dando6)
Dando6.save('accident_heatmap.html')
Dando6
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60345bca4fbcadbb8417216720fbc249 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60345bca4fbcadbb8417216720fbc249&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60345bca4fbcadbb8417216720fbc249 = L.map(
#                 &quot;map_60345bca4fbcadbb8417216720fbc249&quot;,
#                 {
#                     center: [56.147531933333326, -4.1321699333333335],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58d816bfbb722b4d37e902dfe724f425 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_58d816bfbb722b4d37e902dfe724f425.addTo(map_60345bca4fbcadbb8417216720fbc249);
#
#
#             var heat_map_d61ee1291e8cc41e88ea7f23c4657d5a = L.heatLayer(
#                 [[56.109707, -3.961468], [56.295773, -4.293578], [56.137095, -3.87016], [56.005929, -4.355613], [56.253678, -4.280888], [56.061253, -3.857973], [56.411426, -4.318366], [56.086672, -4.367935], [56.141493, -3.911579], [56.059484, -3.920689], [56.130963, -4.068757], [56.031155, -4.417505], [56.224513, -4.20414], [56.083625, -3.940052], [56.180213, -4.213846]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_d61ee1291e8cc41e88ea7f23c4657d5a.addTo(map_60345bca4fbcadbb8417216720fbc249);
#
#
#             tile_layer_58d816bfbb722b4d37e902dfe724f425.addTo(map_60345bca4fbcadbb8417216720fbc249);
#
#
#             heat_map_d61ee1291e8cc41e88ea7f23c4657d5a.addTo(map_60345bca4fbcadbb8417216720fbc249);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <H2>INSIGHT</H2>
# <H3>XXXVI. fatal accidents in Stirling District are highly concentrated around the Stirling town area, with very few fatal accidents occurring in more rural or outlying regions. This suggests that areas with higher traffic density and urban activity are more prone to severe accidents.</H3>
